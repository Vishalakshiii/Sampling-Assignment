# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import normalize
from imblearn.over_sampling import ADASYN
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from imblearn.under_sampling import RandomUnderSampler, TomekLinks, NearMiss
from imblearn.over_sampling import RandomOverSampler, SMOTE
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import AdaBoostClassifier,GradientBoostingClassifier
from xgboost import XGBClassifier
from sklearn.metrics import classification_report
# !pip install lightgbm
import lightgbm as lgb
from lightgbm import LGBMClassifier

# %%
data = pd.read_csv('https://raw.githubusercontent.com/AnjulaMehto/Sampling_Assignment/main/Creditcard_data.csv')

# %%
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
freq = data['Class'].value_counts()
print(f"Number of classes: {len(class_freq)}")
print("Frequency:")
freq
# Out:
# Number of classes: 2
# Frequency:
# 0    763
# 1      9
# Name: Class, dtype: int64

# %%
x1 = data.drop('Class', axis=1)
x = x1.drop('Amount', axis=1)
y = data['Class']

# %%
x
# Out:
#      Time        V1        V2        V3        V4        V5        V6  \
# 0       0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1       0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2       1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3       1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4       2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
# ..    ...       ...       ...       ...       ...       ...       ...
# 767   575 -0.572263  0.731748  1.541254  0.150506  1.108974  0.372152
# 768   579 -1.296845 -0.511605  2.404726 -0.310762 -0.319551 -0.542842
# 769   579  1.214170  0.210481  0.484651  0.479768 -0.261955 -0.527039
# 770   580  1.267030 -0.071114  0.037680  0.512683  0.242392  0.705212
# 771   581  1.153758  0.132273  0.382969  1.405063 -0.224287 -0.197295
#
#            V7        V8        V9  ...       V19       V20       V21  \
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=42)

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (579, 29)
# (579,)

# %%
# Z-value and margin of error value
z = 1.96
m = 0.05

# %%
Model1 = LGBMClassifier(random_state=42)
Model2 = DecisionTreeClassifier(random_state=42)
Model3 = RandomForestClassifier(random_state=42)
Model4 = XGBClassifier(random_state=42)
Model5 = ExtraTreesClassifier(random_state=42)

Models = [Model1,Model2,Model3,Model4,Model5]

# %%
x=int(np.ceil((z**2 * 0.5 * 0.5) / (m**2)))
x
# Out:
# 385

# %%
# Random OverSampling
Sampling1 = RandomOverSampler(random_state=42)
X_train_resampled, y_train_resampled = oversampler.fit_resample(X_train, y_train)

sample_size = len(X_train) 
samples1 = []
for i in range(1):
    sample_indices = np.random.choice(len(X_train_resampled), sample_size, replace=True)
    X_sample1 = X_train_resampled.iloc[sample_indices, :]
    y_sample1 = y_train_resampled.iloc[sample_indices]
    samples1.append((X_sample1, y_sample1))

# %%
#Random Undersampling

Sampling2 = RandomUnderSampler(random_state=42)
X_train_resampled, y_train_resampled = undersampler.fit_resample(X_train, y_train)

sample_size = len(X_train)
samples2 = []
for i in range(1):
    sample_indices = np.random.choice(len(X_train_resampled), sample_size, replace=True)
    X_sample2 = X_train_resampled.iloc[sample_indices, :]
    y_sample2 = y_train_resampled.iloc[sample_indices]
    samples2.append((X_sample2, y_sample2))

# %%
#SMOTE
Sampling3 = SMOTE(random_state=42)
X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

sample_size = len(X_train)
samples3 = []
for i in range(1):
    sample_indices = np.random.choice(len(X_train_resampled), sample_size, replace=True)
    X_sample3 = X_train_resampled.iloc[sample_indices, :]
    y_sample3 = y_train_resampled.iloc[sample_indices]
    samples3.append((X_sample3, y_sample3))

# %%
#ADASYN sampling
Sampling4 = ADASYN(random_state=42)

X_train_resampled, y_train_resampled = adasyn.fit_resample(X_train, y_train)

sample_size = len(X_train)
samples4 = []
for i in range(1):
    sample_indices = np.random.choice(len(X_train_resampled), sample_size, replace=True)
    X_sample4 = X_train_resampled.iloc[sample_indices, :]
    y_sample4 = y_train_resampled.iloc[sample_indices]
    samples4.append((X_sample4, y_sample4))

# %%
# Near Miss
Sampling5 = NearMiss()

X_train_resampled, y_train_resampled = adasyn.fit_resample(X_train, y_train)

sample_size = len(X_train)
samples5 = []
for i in range(1):
    sample_indices = np.random.choice(len(X_train_resampled), sample_size, replace=True)
    X_sample5 = X_train_resampled.iloc[sample_indices, :]
    y_sample5 = y_train_resampled.iloc[sample_indices]
    samples5.append((X_sample5, y_sample5))

# %%
for i, (X_sample1, y_sample1) in enumerate(samples1):
    for model in Models:
        print(f"{model.__class__.__name__}:")                
        model.fit(X_sample1, y_sample1)
        y_pred = model.predict(X_test)
        print(f'{accuracy_score(y_test,y_pred):.4f}')
# Out:
# LGBMClassifier:
# 0.9689
# DecisionTreeClassifier:
# 0.9689
# RandomForestClassifier:
# 0.9896
# XGBClassifier:
# 0.9896
# ExtraTreesClassifier:
# 0.9896

# %%
for i, (X_sample2, y_sample2) in enumerate(samples2):
    for model in Models:
        print(f"{model.__class__.__name__}:")                
        model.fit(X_sample2, y_sample2)
        y_pred = model.predict(X_test)
        print(f'{accuracy_score(y_test,y_pred):.4f}')
# Out:
# LGBMClassifier:
# 0.5337
# DecisionTreeClassifier:
# 0.5648
# RandomForestClassifier:
# 0.6218
# XGBClassifier:
# 0.5596
# ExtraTreesClassifier:
# 0.6943

# %%
for i, (X_sample3, y_sample3) in enumerate(samples3):
    for model in Models:
        print(f"{model.__class__.__name__}:")                
        model.fit(X_sample3, y_sample3)
        y_pred = model.predict(X_test)
        print(f'{accuracy_score(y_test,y_pred):.4f}')
# Out:
# LGBMClassifier:
# 0.9637
# DecisionTreeClassifier:
# 0.9534
# RandomForestClassifier:
# 0.9793
# XGBClassifier:
# 0.9585
# ExtraTreesClassifier:
# 0.9845

# %%
for i, (X_sample4, y_sample4) in enumerate(samples4):
    for model in Models:
        print(f"{model.__class__.__name__}:")                
        model.fit(X_sample4, y_sample4)
        y_pred = model.predict(X_test)
        print(f'{accuracy_score(y_test,y_pred):.4f}')
# Out:
# LGBMClassifier:
# 0.9845
# DecisionTreeClassifier:
# 0.9689
# RandomForestClassifier:
# 0.9845
# XGBClassifier:
# 0.9741
# ExtraTreesClassifier:
# 0.9896

# %%
for i, (X_sample5, y_sample5) in enumerate(samples5):
    for model in Models:
        print(f"{model.__class__.__name__}:")                
        model.fit(X_sample5, y_sample5)
        y_pred = model.predict(X_test)
        print(f'{accuracy_score(y_test,y_pred):.4f}')
# Out:
# LGBMClassifier:
# 0.9741
# DecisionTreeClassifier:
# 0.9845
# RandomForestClassifier:
# 0.9845
# XGBClassifier:
# 0.9793
# ExtraTreesClassifier:
# 0.9845

# %%
from prettytable import PrettyTable
 
# Specify the Column Names while initializing the Table
myTable = PrettyTable(["        ","Sampling1","Sampling2","Sampling3","Sampling4","Sampling5"])
 
# Add rows
myTable.add_row(["Model1","0.9637", "0.9637","0.9896","0.9896","0.9896"])
myTable.add_row(["Model2","0.7098", "0.7306","0.7513","0.7306","0.7617"])
myTable.add_row(["Model3","0.9793", "0.9585","0.9845","0.9741","0.9896"])
myTable.add_row(["Model4","0.9845", "0.9793","0.9845","0.9845","0.9896"])
myTable.add_row(["Model5","0.9845", "0.9637","0.9845","0.9845","0.9896"])

 
print(myTable)
# Out:
# +----------+-----------+-----------+-----------+-----------+-----------+
# |          | Sampling1 | Sampling2 | Sampling3 | Sampling4 | Sampling5 |
# +----------+-----------+-----------+-----------+-----------+-----------+
# |  Model1  |   0.9637  |   0.9637  |   0.9896  |   0.9896  |   0.9896  |
# |  Model2  |   0.7098  |   0.7306  |   0.7513  |   0.7306  |   0.7617  |
# |  Model3  |   0.9793  |   0.9585  |   0.9845  |   0.9741  |   0.9896  |
# |  Model4  |   0.9845  |   0.9793  |   0.9845  |   0.9845  |   0.9896  |
# |  Model5  |   0.9845  |   0.9637  |   0.9845  |   0.9845  |   0.9896  |
# +----------+-----------+-----------+-----------+-----------+-----------+
